# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
data = pd.read_csv(r"C:\Users\Shaik Sakhlaih\Downloads\titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
imputer = SimpleImputer(strategy='most_frequent')
data['Age'] = imputer.fit_transform(data[['Age']])

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Cabin'].mode()[0]
# Out:
# 'B96 B98'

# %%
data['Cabin'] = data['Cabin'].fillna('B98')

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
data['Embarked'].mode()[0]
# Out:
# 'S'

# %%
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
from sklearn.preprocessing import OrdinalEncoder

ol = OrdinalEncoder()

data['Pclass'] = ol.fit_transform(data[['Pclass']]).astype(int)

data['Pclass'].value_counts()
# Out:
# Pclass
# 2    491
# 0    216
# 1    184
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

data['Name'] = le.fit_transform(data['Name'])
data['Cabin'] = le.fit_transform(data['Cabin'])
data['Ticket'] = le.fit_transform(data['Ticket'])


a = data['Name'].value_counts()
b = data['Cabin'].value_counts()
c = data['Ticket'].value_counts()

print(a)
print(b)
print(c)
# Out:
# Name
# 220    1
# 108    1
# 190    1
# 353    1
# 272    1
#       ..
# 359    1
# 840    1
# 28     1
# 729    1
# 95     1
# Name: count, Length: 891, dtype: int64
# Cabin
# 48     687
# 146      4
# 64       4
# 47       4
# 142      3
#       ...
# 120      1
# 6        1
# 71       1
# 30       1
# 61       1
# Name: count, Length: 148, dtype: int64
# Ticket
# 333    7
# 80     7
# 568    7
# 249    6
# 566    6
#       ..
# 590    1
# 85     1
# 275    1
# 472    1
# 669    1
# Name: count, Length: 681, dtype: int64

# %%
data['Age'] = data['Age'].astype(int)
data['Fare'] = data['Fare'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    int64
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    int64
#  9   Fare         891 non-null    int64
#  10  Cabin        891 non-null    int64
#  11  Embarked     891 non-null    object
# dtypes: int64(10), object(2)
# memory usage: 83.7+ KB

# %%
data = pd.get_dummies(data, columns = ['Sex'], drop_first = True)

# %%
data['Sex_male'].value_counts()
# Out:
# Sex_male
# True     577
# False    314
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# 0            1         0       2   108   22      1      0     523     7
# 1            2         1       0   190   38      1      0     596    71
# 2            3         1       2   353   26      0      0     669     7
# 3            4         1       0   272   35      1      0      49    53
# 4            5         0       2    15   35      0      0     472     8
#
#    Cabin Embarked  Sex_male
# 0     48        S      True
# 1     82        C     False
# 2     48        S     False
# 3     56        S     False
# 4     48        S      True

# %%
data['Sex_male'] = data['Sex_male'].astype(int)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# 0            1         0       2   108   22      1      0     523     7
# 1            2         1       0   190   38      1      0     596    71
# 2            3         1       2   353   26      0      0     669     7
# 3            4         1       0   272   35      1      0      49    53
# 4            5         0       2    15   35      0      0     472     8
#
#    Cabin Embarked  Sex_male
# 0     48        S         1
# 1     82        C         0
# 2     48        S         0
# 3     56        S         0
# 4     48        S         1

# %%
data = pd.get_dummies(data, columns = ['Embarked'], drop_first = True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# 0            1         0       2   108   22      1      0     523     7
# 1            2         1       0   190   38      1      0     596    71
# 2            3         1       2   353   26      0      0     669     7
# 3            4         1       0   272   35      1      0      49    53
# 4            5         0       2    15   35      0      0     472     8
#
#    Cabin  Sex_male  Embarked_Q  Embarked_S
# 0     48         1       False        True
# 1     82         0       False       False
# 2     48         0       False        True
# 3     56         0       False        True
# 4     48         1       False        True

# %%
data[['Embarked_Q', 'Embarked_S']] = data[['Embarked_Q','Embarked_S']].astype(int)

# %%
data.head(1)
# Out:
#    PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# 0            1         0       2   108   22      1      0     523     7
#
#    Cabin  Sex_male  Embarked_Q  Embarked_S
# 0     48         1           0           1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    int64
#  4   Age          891 non-null    int64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    int64
#  8   Fare         891 non-null    int64
#  9   Cabin        891 non-null    int64
#  10  Sex_male     891 non-null    int64
#  11  Embarked_Q   891 non-null    int64
#  12  Embarked_S   891 non-null    int64
# dtypes: int64(13)
# memory usage: 90.6 KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor

x =  data.drop(['Survived'], axis = 1)
y = data['Survived']

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.2, random_state = 0)

a = x_train.shape, x_test.shape
b = y_train.shape, y_test.shape

print(a)
print(b)
# Out:
# ((178, 12), (713, 12))
# ((178,), (713,))

# %%
gbs = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0)

model = gbs.fit(x_train, y_train)

model
# Out:
# GradientBoostingRegressor()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 2.19169281e-01, -1.18553907e-01,  1.53440248e-01,  8.90145334e-01,
#         1.00300901e+00,  2.88648949e-01,  8.69586380e-01,  7.09140116e-01,
#         1.08899325e+00,  9.24278242e-01,  8.44128887e-02,  9.27592600e-01,
#         8.70810433e-02,  1.11511316e+00,  1.06671186e+00,  9.67490531e-01,
#         3.16432716e-01,  2.38117795e-02,  1.23274653e-01,  7.20238542e-01,
#         3.58158035e-01,  1.15429696e+00,  1.06063942e-01,  9.52544224e-01,
#         9.14830240e-01,  1.06685313e+00,  1.49553535e-01,  5.03250585e-01,
#         9.98721306e-01,  7.83857713e-01,  3.04590162e-02,  5.78941509e-01,
#         8.94695984e-01,  4.64778590e-01,  9.27366472e-01,  1.15318269e+00,
#         7.98994918e-02,  1.81273127e-01,  7.21982274e-01,  1.16269661e+00,
#         2.33043703e-01,  1.33133040e+00,  7.11914643e-01,  1.63152363e-01,
#         1.42922454e-01, -1.21026451e-02,  2.72546380e-01,  8.44146229e-01,
#         1.63695433e-01,  1.87742521e-01, -2.18665721e-01,  1.38503561e-01,
#         1.06609129e+00,  7.39239853e-01,  1.02947066e+00,  9.40685293e-01,
#         1.23553399e+00,  9.55023132e-01,  1.04149152e-01,  3.12805187e-01,
#         3.92551663e-01,  7.07615027e-01,  4.40338084e-01,  4.82514697e-01,
#         1.36565190e-02,  9.24352106e-01,  7.28419001e-01,  9.39026561e-01,
#         1.08363001e-01,  2.76299676e-01,  2.46976557e-01,  3.07264771e-02,
#         4.30859391e-01,  8.49492014e-01,  6.04933861e-01,  4.24685576e-01,
#         2.96028262e-02,  2.75166754e-01,  1.14319612e-01,  1.64981621e-03,
#         1.11829742e+00,  1.18697752e+00,  9.21077466e-02,  7.56886277e-01,
#         2.94680570e-01,  1.00411101e+00,  2.84659188e-01,  3.86872385e-01,
#         5.41832596e-02,  3.89979440e-01,  5.73278716e-01,  9.82854954e-01,
#         9.25162917e-01,  1.01352557e+00,  1.00822427e+00, -1.56575997e-02,
#         1.00386526e+00,  1.59412697e-01,  5.57727421e-04,  5.75779005e-01,
#         1.14779804e+00,  1.46432604e-01,  6.66490149e-01,  1.04506120e-01,
#         1.95535579e-01,  2.81256665e-01,  6.03937568e-02,  7.28040386e-01,
#         9.10115731e-01,  9.21840198e-02,  2.61447556e-01,  1.26410199e+00,
#         1.62316682e-01,  9.21392197e-02, -3.08481493e-02,  1.73412216e-01,
#         2.87512075e-02,  3.31037040e-01, -8.22848381e-02,  1.10764768e-01,
#         7.54192626e-01,  7.51479804e-01,  1.66400271e-01,  1.01845602e-01,
#         9.97628165e-02,  4.76020035e-02,  8.53921664e-01,  1.22352831e+00,
#         2.95865189e-01, -8.25667100e-02,  2.37948173e-01,  1.09209412e+00,
#         1.08600159e+00,  2.17997567e-01,  7.28358903e-01,  2.01703050e-02,
#         8.24677489e-01,  8.38312026e-01,  5.94477456e-01,  9.25903476e-01,
#         2.33686586e-01, -2.63693311e-03,  1.16932639e+00, -5.10161358e-02,
#        -3.72421318e-02,  1.13721701e+00,  4.21267780e-01,  6.37466666e-02,
#         1.13643693e-01,  7.81912266e-01, -1.05564936e-01,  1.60354267e-01,
#         1.22342845e-01,  1.46371490e-01,  2.19283729e-01, -9.23712302e-02,
#         1.23134292e-01])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("The mean squared error :",mse)
# Out:
# The mean squared error : 0.20517449361837975

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)*10

print(f" Accuracy of R2_Score = {r2}")
# Out:
#  Accuracy of R2_Score = 1.1585501520460717
